# %%
#Task1
# Create a bar chart or histogram to visualize the distribution of a categorical or continuous variable 
#such as the distribution of ages or genders in a population.

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df1 = pd.read_csv('standard_populations_19_age_groups.csv')
df1.head()
# Out:
#   age_group  1940 U.S. Std Million  1950 U.S. Std Million  \
# 0         0                  15343                  20882
# 1     01-04                  64718                  86376
# 2     05-09                  81147                  87591
# 3     10-14                  89208                  73785
# 4     15-19                  93670                  70450
#
#    1960 U.S. Std Million  1970 U.S. Std Million  1980 U.S. Std Million  \
# 0                  22930                  17151                  15598
# 1                  90390                  67265                  56565
# 2                 104235                  98204                  73716
# 3                  93538                 102304                  80523
# 4                  73717                  93845                  93439
#
#    1990 U.S. Std Million  1991 Canadian Std Million  \
# 0                  12936                      14334
# 1                  60863                      55131
# ...

# %%
df1.shape
# Out:
# (19, 17)

# %%
age_groups = df1['age_group']
population_2000_us = df1['2000 U.S. Std Million']

plt.figure(figsize=(12, 6))
plt.bar(age_groups, population_2000_us, color='teal', edgecolor='black')

plt.title("Age Distribution - 2000 U.S. Standard Population", fontsize=12)
plt.xlabel("Age Group")
plt.ylabel("Population (in Millions)")
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.hist(df['2000 U.S. Std Million'], bins=10, color='skyblue', edgecolor='black')

plt.title("Histogram of Age Distribution - 2000 U.S. Standard Population", fontsize=14)
plt.xlabel("Population Range (in Millions)")
plt.ylabel("Number of Age Groups")
plt.show()
